# %%
import os
from dotenv import load_dotenv
from mlflow import MlflowClient

# Load environment variables from .env file
load_dotenv()

# Verify environment variables are loaded
print(f"MLFLOW_TRACKING_URI: {os.getenv('MLFLOW_TRACKING_URI')}")
print(f"MLFLOW_TRACKING_TOKEN: {'*' * 20 if os.getenv('MLFLOW_TRACKING_TOKEN') else 'Not set'}")
# Out:
# MLFLOW_TRACKING_URI: https://gitlab.cern.ch/api/v4/projects/222677/ml/mlflow/
# MLFLOW_TRACKING_TOKEN: ********************

# %%
client = MlflowClient()

# %%
# model_name = "b2bH-vlq-xgboost-model"
# description = "XGBoost model for b2bH to vlq analysis"
# model = client.create_registered_model(model_name, description=description)
# exp = client.get_experiment_by_name(f"[model]{model_name}")
# run = client.create_run(experiment_id=exp.experiment_id)

# %%
import mlflow

experiment_id = mlflow.create_experiment(name="xgboost-tHq-bkg")

mlflow.set_experiment(experiment_id=experiment_id)
# Out:
# ---------------------------------------------------------------------------
# RestException                             Traceback (most recent call last)
# Cell In[3], line 3
#       1 import mlflow
# ----> 3 experiment_id = mlflow.create_experiment(name="xgboost-tHq-bkg")
#       5 mlflow.set_experiment(experiment_id=experiment_id)
#
# File ~/work/CMS/b2bH-vlq/.venv/lib/python3.13/site-packages/mlflow/tracking/fluent.py:2114, in create_experiment(name, artifact_location, tags)
#    2066 def create_experiment(
#    2067     name: str,
#    2068     artifact_location: str | None = None,
#    2069     tags: dict[str, Any] | None = None,
#    2070 ) -> str:
#    2071     """
#    2072     Create an experiment.
#    2073
#    (...)   2112         Creation timestamp: 1662004217511
#    2113     """
# -> 2114     return MlflowClient().create_experiment(name, artifact_location, tags)
#
# File ~/work/CMS/b2bH-vlq/.venv/lib/python3.13/site-packages/mlflow/tracking/client.py:1852, in MlflowClient.create_experiment(self, name, artifact_location, tags)
#    1800 def create_experiment(
#    1801     self,
#    1802     name: str,
#    1803     artifact_location: str | None = None,
#    1804     tags: dict[str, Any] | None = None,
#    1805 ) -> str:
#    1806     """Create an experiment.
#    1807
#    1808     Args:
#    (...)   1850
#    1851     """
# -> 1852     return self._tracking_client.create_experiment(name, artifact_location, tags)
#
# File ~/work/CMS/b2bH-vlq/.venv/lib/python3.13/site-packages/mlflow/telemetry/track.py:30, in record_usage_event.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#      28 start_time = time.time()
#      29 try:
# ---> 30     result = func(*args, **kwargs)
#      31     return result  # noqa: RET504
#      32 except Exception:
#
# File ~/work/CMS/b2bH-vlq/.venv/lib/python3.13/site-packages/mlflow/tracking/_tracking_service/client.py:298, in TrackingServiceClient.create_experiment(self, name, artifact_location, tags)
#     284 """Create an experiment.
#     285
#     286 Args:
#    (...)    295
#     296 """
#     297 _validate_experiment_artifact_location(artifact_location)
# --> 298 return self.store.create_experiment(
#     299     name=name,
#     300     artifact_location=artifact_location,
#     301     tags=[ExperimentTag(key, value) for (key, value) in tags.items()] if tags else [],
#     302 )
#
# File ~/work/CMS/b2bH-vlq/.venv/lib/python3.13/site-packages/mlflow/store/tracking/rest_store.py:254, in RestStore.create_experiment(self, name, artifact_location, tags)
#     250 tag_protos = [tag.to_proto() for tag in tags] if tags else []
#     251 req_body = message_to_json(
#     252     CreateExperiment(name=name, artifact_location=artifact_location, tags=tag_protos)
#     253 )
# --> 254 response_proto = self._call_endpoint(CreateExperiment, req_body)
#     255 return response_proto.experiment_id
#
# File ~/work/CMS/b2bH-vlq/.venv/lib/python3.13/site-packages/mlflow/store/tracking/rest_store.py:203, in RestStore._call_endpoint(self, api, json_body, endpoint, retry_timeout_seconds, response_proto)
#     201     endpoint, method = self._METHOD_TO_INFO[api]
#     202 response_proto = response_proto or api.Response()
# --> 203 return call_endpoint(
#     204     self.get_host_creds(),
#     205     endpoint,
#     206     method,
#     207     json_body,
#     208     response_proto,
#     209     retry_timeout_seconds=retry_timeout_seconds,
#     210 )
#
# File ~/work/CMS/b2bH-vlq/.venv/lib/python3.13/site-packages/mlflow/utils/rest_utils.py:596, in call_endpoint(host_creds, endpoint, method, json_body, response_proto, extra_headers, retry_timeout_seconds)
#     593     call_kwargs["json"] = json_body
#     594     response = http_request(**call_kwargs)
# --> 596 response = verify_rest_response(response, endpoint)
#     597 response_to_parse = response.text
#     598 try:
#
# File ~/work/CMS/b2bH-vlq/.venv/lib/python3.13/site-packages/mlflow/utils/rest_utils.py:315, in verify_rest_response(response, endpoint)
#     313 if response.status_code != 200:
#     314     if _can_parse_as_json_object(response.text):
# --> 315         raise RestException(json.loads(response.text))
#     316     else:
#     317         base_msg = (
#     318             f"API request to endpoint {endpoint} "
#     319             f"failed with error code {response.status_code} != 200"
#     320         )
#
# RestException: RESOURCE_ALREADY_EXISTS: Response: {'error_code': 'RESOURCE_ALREADY_EXISTS'}

# %%
import uproot

t_sig = uproot.open("../data/BDT_tree_M800_14TeV.root:BbH_tree")
t_bkg = uproot.open("../data/BKG_tree_tHq_14TeV.root:BbH_tree")

# %%
df_sig = t_sig.arrays(library="pd")
df_bkg = t_bkg.arrays(library="pd")

# %%
w_sig = df_sig["evt_weight"]
w_bkg = df_bkg["evt_weight"]

# %%
# Convert multiplicity columns to integers
df_sig = df_sig.astype({
    'n_bjet': 'int32',
    'n_jets': 'int32',
    'n_fjet': 'int32',
},)
df_bkg = df_bkg.astype({
    'n_bjet': 'int32',
    'n_jets': 'int32',
    'n_fjet': 'int32',
},)

# %% [markdown]
# Select as input features kinematic variables $p_{T}$ and $\eta$ from  the VLQ candidate and its decay products.
# Also include $H_{T}$ and deltaR between b-jet and Higgs candidates.

# %%
import matplotlib.pyplot as plt
from itertools import product
from sklearn.model_selection import train_test_split

from b2bH_vlq import get_variable_group_names, get_variables_by_group
from hepkit.classification.visualization import plot_signal_background_comparison
from hepkit.classification.preprocessing import prepare_training_data, split_train_test_by_unique_id
from hepkit.histograms import hist1d_from_var

# %%
all_vars = {}
for gr in get_variable_group_names():
    all_vars.update(get_variables_by_group(gr))
all_vars.keys();

# %%
cands = ["photon1", "photon2", "diphoton", "bjet", "VLQ"]
obs = ["pt", "eta"]

mva_vars = { }
for cand, obs in product(cands, obs):
    key = f"{cand}_{obs}"
    mva_vars[key] = all_vars[key]
mva_vars["HT"] = all_vars["HT"]
mva_vars["deltaR_bjet_Higgs"] = all_vars["deltaR_bjet_Higgs"]
mva_vars.keys();

# %%
mva_names = list(mva_vars.keys())
sig_mva_hist = {}
bkg_mva_hist = {}
for name in mva_names:
    var = mva_vars[name]
    sig_mva_hist[name] = hist1d_from_var(var, df_sig)
    bkg_mva_hist[name] = hist1d_from_var(var, df_bkg)

# %%
Xy, ids = prepare_training_data(
    df_sig,
    df_bkg,
    mva_vars.values(),
    mva_vars.values(),
    sig_weights=w_sig,
    bkg_weights=w_bkg,
    id_columns=["NEvts"]
)

# %%
train_set, test_set = split_train_test_by_unique_id(
    Xy, ids, test_ratio=0.2, id_columns=["NEvts"], 
)

# Define the training and validation sets
train_X, val_X, train_y, val_y = train_test_split(
    train_set.drop("label", axis=1), train_set["label"], test_size=0.2, random_state=42
)

train_weights = train_X.pop("weights")
val_weights = val_X.pop("weights")

# %%
mlflow.sklearn.autolog()

# %%
import xgboost as xgb

# %%
with mlflow.start_run(run_name="run1"):
    fig, axes = plot_signal_background_comparison(
        sig_mva_hist, bkg_mva_hist, subplot_titles=False
    )
    plt.tight_layout()
    plot_filename = "mva_variable_distributions.png"
    plt.savefig(plot_filename)
    mlflow.log_artifact(plot_filename)
    plt.close()

    model_xgb = xgb.XGBClassifier(
        n_estimators=2500,
        max_depth=2,
        learning_rate=0.05,
        random_state=42,
        early_stopping_rounds=100,
    )

    model_xgb.fit(train_X, train_y, eval_set=[(val_X, val_y)], verbose=False);
